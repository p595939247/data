# %% [markdown]
# # **Final exam 題目說明：**
# ### **使用深度學習模型對kaggle上的twitter資料集進行情緒分析，預測的文本情緒分為三類：Positive、Neutral、Negative，最後進行模型評估，需包含(precision    recall  f1-score   support)但不限於這幾種評估指標**
#
# Twitter資料集：
# https://www.kaggle.com/datasets/jp797498e/twitter-entity-sentiment-analysis

# %% [markdown]
# ## 讀取資料(輸出訓練集的基本資訊) 10%
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 檢查資料的完整性(處理缺失值並輸出處理後的資訊) 10%
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 分析每個情緒的分佈(可視化統計情緒的頻率) 20%
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 對文本進行預處理(去除停用詞,使用標籤編碼使情緒(正面﹑負面)轉為向量) 20%
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 將"twitter_training"分割為訓練集和驗證集並選擇模型進行訓練 20%
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 模型評估(使用測試集評估模型的表現) 20%
# ![image.png](attachment:image.png)
#
# (Accurancy 95%: 20%; Accurancy ~85%: 15%; Accurancy ~75%:10%; Accurancy ~65%: 5%)
